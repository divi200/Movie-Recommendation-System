# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Movies from 2020

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2020"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
df
# Out:
#       Opening  Opening.1                  Title  \
# 0     JANUARY          3             The Grudge
# 1     JANUARY         10             Underwater
# 2     JANUARY         10            Like a Boss
# 3     JANUARY         10          Three Christs
# 4     JANUARY         10      Inherit the Viper
# ..        ...        ...                    ...
# 269  DECEMBER         25       We Can Be Heroes
# 270  DECEMBER         25      News of the World
# 271  DECEMBER         25  One Night in Miami...
# 272  DECEMBER         25  Promising Young Woman
# 273  DECEMBER         30      Pieces of a Woman
#
#                                     Production company  \
# 0    Screen Gems / Stage 6 Films / Ghost House Pict...
# 1    20th Century Fox / TSG Entertainment / Chernin...
# 2                                   Paramount Pictures
# 3                                            IFC Films
# 4       Barry Films / Tycor International Film Company
# ..                                                 ...
# 269                     Netflix / Troublemaker Studios
# 270        Universal Pictures / Perfect World Pictures
# 271                                     Amazon Studios
# 272          Focus Features / FilmNation Entertainment
# 273                             Netflix / Bron Studios
#
#                                          Cast and crew  \
# 0    Nicolas Pesce (director/screenplay); Andrea Ri...
# 1    William Eubank (director); Brian Duffield, Ada...
# 2    Miguel Arteta (director); Sam Pitman, Adam Col...
# 3    Jon Avnet (director/screenplay); Eric Nazarian...
# 4    Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                                                 ...
# 269  Robert Rodriguez (director/screenplay); Priyan...
# 270  Paul Greengrass (director/screenplay); Luke Da...
# 271  Regina King (director); Kemp Powers (screenpla...
# 272  Emerald Fennell (director/screenplay); Carey M...
# 273  Kornél Mundruczó (director); Kata Wéber (scree...
#
#     .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Ref.  \
# 0                                                  [2]
# 1                                                  [3]
# 2                                                  [4]
# 3                                                  NaN
# 4                                                  [5]
# ..                                                 ...
# 269                                                NaN
# 270                                                NaN
# 271                                                NaN
# 272                                                NaN
# 273                                                NaN
#
#       Ref.
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ..     ...
# 269  [241]
# 270  [242]
# 271  [243]
# 272  [244]
# 273  [245]
#
# [274 rows x 7 columns]

# %%
# !pip install tmdbv3api
# Out:
# Collecting tmdbv3api
#   Downloading tmdbv3api-1.7.6-py2.py3-none-any.whl (17 kB)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from tmdbv3api) (2.24.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->tmdbv3api) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->tmdbv3api) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->tmdbv3api) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests->tmdbv3api) (3.0.4)
# Installing collected packages: tmdbv3api
# Successfully installed tmdbv3api-1.7.6

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = 'ee7a5c522f32979675098febc3677f3b'

# %%
from tmdbv3api import Movie
tmdb_movie = Movie()
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    if len(result) != 0:
        movie_id = result[0].id
        response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
        data_json = response.json()
        if data_json['genres']:
            genre_str = " " 
            for i in range(0,len(data_json['genres'])):
                genres.append(data_json['genres'][i]['name'])
            return genre_str.join(genres)
        else:
            return np.NaN
    else:
        return np.NaN

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))

# %%
df['genres'][128]
# Out:
# nan

# %%
df_2020 = df[['Title','Cast and crew','genres']]

# %%
df_2020
# Out:
#                      Title                                      Cast and crew  \
# 0               The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               Underwater  William Eubank (director); Brian Duffield, Ada...
# 2              Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
# 269       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 270      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 271  One Night in Miami...  Regina King (director); Kemp Powers (screenpla...
# 272  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 273      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
#                                      genres
# 0                   Horror Mystery Thriller
# 1    Action Horror Science Fiction Thriller
# 2                                    Comedy
# 3                                     Drama
# 4                      Crime Thriller Drama
# ..                                      ...
# 269            Action Fantasy Family Comedy
# 270                 Drama Western Adventure
# 271                                   Drama
# 272                    Thriller Crime Drama
# 273                                   Drama
#
# [274 rows x 3 columns]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2020['director_name'] = df_2020['Cast and crew'].map(lambda x: get_director(x))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2020['actor_1_name'] = df_2020['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2020['actor_2_name'] = df_2020['Cast and crew'].map(lambda x: get_actor2(x))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2020['actor_3_name'] = df_2020['Cast and crew'].map(lambda x: get_actor3(x))
df_2020
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                      Title                                      Cast and crew  \
# 0               The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               Underwater  William Eubank (director); Brian Duffield, Ada...
# 2              Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
# 269       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 270      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 271  One Night in Miami...  Regina King (director); Kemp Powers (screenpla...
# 272  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 273      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
#                                      genres     director_name  \
# 0                   Horror Mystery Thriller     Nicolas Pesce
# 1    Action Horror Science Fiction Thriller    William Eubank
# 2                                    Comedy     Miguel Arteta
# 3                                     Drama         Jon Avnet
# 4                      Crime Thriller Drama    Anthony Jerjen
# ..                                      ...               ...
# 269            Action Fantasy Family Comedy  Robert Rodriguez
# 270                 Drama Western Adventure   Paul Greengrass
# 271                                   Drama       Regina King
# 272                    Thriller Crime Drama   Emerald Fennell
# 273                                   Drama  Kornél Mundruczó
#
#               actor_1_name       actor_2_name     actor_3_name
# 0       Andrea Riseborough      Demián Bichir         John Cho
# 1          Kristen Stewart     Vincent Cassel  Jessica Henwick
# 2          Tiffany Haddish         Rose Byrne      Salma Hayek
# 3             Richard Gere     Peter Dinklage   Walton Goggins
# 4            Josh Hartnett  Margarita Levieva   Chandler Riggs
# ..                     ...                ...              ...
# 269  Priyanka Chopra Jonas       Pedro Pascal    YaYa Gosselin
# 270              Tom Hanks      Helena Zengel              NaN
# 271      Kingsley Ben-Adir          Eli Goree      Aldis Hodge
# 272         Carey Mulligan         Bo Burnham      Alison Brie
# 273          Vanessa Kirby       Shia LaBeouf     Molly Parker
#
# [274 rows x 7 columns]

# %%
df_2020 = df_2020.rename(columns={'Title':'movie_title'})
new_df20 = df_2020.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]
new_df20
# Out:
#         director_name           actor_1_name       actor_2_name  \
# 0       Nicolas Pesce     Andrea Riseborough      Demián Bichir
# 1      William Eubank        Kristen Stewart     Vincent Cassel
# 2       Miguel Arteta        Tiffany Haddish         Rose Byrne
# 3           Jon Avnet           Richard Gere     Peter Dinklage
# 4      Anthony Jerjen          Josh Hartnett  Margarita Levieva
# ..                ...                    ...                ...
# 269  Robert Rodriguez  Priyanka Chopra Jonas       Pedro Pascal
# 270   Paul Greengrass              Tom Hanks      Helena Zengel
# 271       Regina King      Kingsley Ben-Adir          Eli Goree
# 272   Emerald Fennell         Carey Mulligan         Bo Burnham
# 273  Kornél Mundruczó          Vanessa Kirby       Shia LaBeouf
#
#         actor_3_name                                  genres  \
# 0           John Cho                 Horror Mystery Thriller
# 1    Jessica Henwick  Action Horror Science Fiction Thriller
# 2        Salma Hayek                                  Comedy
# 3     Walton Goggins                                   Drama
# 4     Chandler Riggs                    Crime Thriller Drama
# ..               ...                                     ...
# 269    YaYa Gosselin            Action Fantasy Family Comedy
# 270              NaN                 Drama Western Adventure
# 271      Aldis Hodge                                   Drama
# 272      Alison Brie                    Thriller Crime Drama
# 273     Molly Parker                                   Drama
#
#                movie_title
# 0               The Grudge
# 1               Underwater
# 2              Like a Boss
# 3            Three Christs
# 4        Inherit the Viper
# ..                     ...
# 269       We Can Be Heroes
# 270      News of the World
# 271  One Night in Miami...
# 272  Promising Young Woman
# 273      Pieces of a Woman
#
# [274 rows x 6 columns]

# %%
new_df20['actor_2_name'] = new_df20['actor_2_name'].replace(np.nan, 'unknown')
new_df20['actor_3_name'] = new_df20['actor_3_name'].replace(np.nan, 'unknown')
new_df20['movie_title'] = new_df20['movie_title'].str.lower()
new_df20['comb'] = new_df20['actor_1_name'] + ' ' + new_df20['actor_2_name'] + ' '+ new_df20['actor_3_name'] + ' '+ new_df20['director_name'] +' ' + new_df20['genres']
new_df20
# Out:
#         director_name           actor_1_name       actor_2_name  \
# 0       Nicolas Pesce     Andrea Riseborough      Demián Bichir
# 1      William Eubank        Kristen Stewart     Vincent Cassel
# 2       Miguel Arteta        Tiffany Haddish         Rose Byrne
# 3           Jon Avnet           Richard Gere     Peter Dinklage
# 4      Anthony Jerjen          Josh Hartnett  Margarita Levieva
# ..                ...                    ...                ...
# 269  Robert Rodriguez  Priyanka Chopra Jonas       Pedro Pascal
# 270   Paul Greengrass              Tom Hanks      Helena Zengel
# 271       Regina King      Kingsley Ben-Adir          Eli Goree
# 272   Emerald Fennell         Carey Mulligan         Bo Burnham
# 273  Kornél Mundruczó          Vanessa Kirby       Shia LaBeouf
#
#         actor_3_name                                  genres  \
# 0           John Cho                 Horror Mystery Thriller
# 1    Jessica Henwick  Action Horror Science Fiction Thriller
# 2        Salma Hayek                                  Comedy
# 3     Walton Goggins                                   Drama
# 4     Chandler Riggs                    Crime Thriller Drama
# ..               ...                                     ...
# 269    YaYa Gosselin            Action Fantasy Family Comedy
# 270          unknown                 Drama Western Adventure
# 271      Aldis Hodge                                   Drama
# 272      Alison Brie                    Thriller Crime Drama
# 273     Molly Parker                                   Drama
#
#                movie_title                                               comb
# 0               the grudge  Andrea Riseborough Demián Bichir John Cho Nico...
# 1               underwater  Kristen Stewart Vincent Cassel Jessica Henwick...
# 2              like a boss  Tiffany Haddish Rose Byrne Salma Hayek Miguel ...
# 3            three christs  Richard Gere Peter Dinklage Walton Goggins Jon...
# 4        inherit the viper  Josh Hartnett Margarita Levieva Chandler Riggs...
# ..                     ...                                                ...
# 269       we can be heroes  Priyanka Chopra Jonas Pedro Pascal YaYa Gossel...
# 270      news of the world  Tom Hanks Helena Zengel unknown Paul Greengras...
# 271  one night in miami...  Kingsley Ben-Adir Eli Goree Aldis Hodge Regina...
# 272  promising young woman  Carey Mulligan Bo Burnham Alison Brie Emerald ...
# 273      pieces of a woman  Vanessa Kirby Shia LaBeouf Molly Parker Kornél...
#
# [274 rows x 7 columns]

# %% [markdown]
# ### Movies from 2021

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2021"
df1 = pd.read_html(link, header=0)[3]
df2 = pd.read_html(link, header=0)[4]
df3 = pd.read_html(link, header=0)[5]
df4 = pd.read_html(link, header=0)[6]

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
df
# Out:
#       Opening  Opening.1                   Title  \
# 0     JANUARY        1.0     Shadow in the Cloud
# 1     JANUARY       13.0         The White Tiger
# 2     JANUARY       14.0             Locked Down
# 3     JANUARY       15.0                 The Dig
# 4     JANUARY       15.0        Outside the Wire
# ..        ...        ...                     ...
# 353  DECEMBER       25.0  The Tragedy of Macbeth
# 354  DECEMBER       25.0    A Journal for Jordan
# 355  DECEMBER       25.0       American Underdog
# 356  DECEMBER       26.0                 Memoria
# 357  DECEMBER        NaN                     NaN
#
#                                     Production company  \
# 0                               Vertical Entertainment
# 1                                              Netflix
# 2                      HBO Max / Warner Bros. Pictures
# 3                          Netflix / Clerkenwell Films
# 4                                              Netflix
# ..                                                 ...
# 353                        Apple TV+ / A24 / IAC Films
# 354  Columbia Pictures / Escape Artists / Bron Studios
# 355                                          Lionsgate
# 356                                               Neon
# 357                                                NaN
#
#                                          Cast and crew  \
# 0    Roseanne Liang (director/screenplay); Max Land...
# 1    Ramin Bahrani (director/screenplay); Adarsh Go...
# 2    Doug Liman (director); Steven Knight (screenpl...
# 3    Simon Stone (director); Moira Buffini (screenp...
# 4    Mikael Håfström (director); Rob Yescombe, Rowa...
# ..                                                 ...
# 353  Joel Coen (director/screenplay); Denzel Washin...
# 354  Denzel Washington (director); Virgil Williams ...
# 355  Erwin brothers (directors); Jon Erwin, David A...
# 356  Apichatpong Weerasethakul (director/acreenplay...
# 357                                                NaN
#
#     .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Ref.  \
# 0                                                  [2]
# 1                                                  NaN
# 2                                                  [3]
# 3                                                  [4]
# 4                                                  [5]
# ..                                                 ...
# 353                                                NaN
# 354                                                NaN
# 355                                                NaN
# 356                                                NaN
# 357                                                NaN
#
#       Ref.
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ..     ...
# 353  [271]
# 354  [272]
# 355  [273]
# 356  [274]
# 357    NaN
#
# [358 rows x 7 columns]

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))
df_2021 = df[['Title','Cast and crew','genres']]
df_2021
# Out:
#                       Title  \
# 0       Shadow in the Cloud
# 1           The White Tiger
# 2               Locked Down
# 3                   The Dig
# 4          Outside the Wire
# ..                      ...
# 353  The Tragedy of Macbeth
# 354    A Journal for Jordan
# 355       American Underdog
# 356                 Memoria
# 357                     NaN
#
#                                          Cast and crew  \
# 0    Roseanne Liang (director/screenplay); Max Land...
# 1    Ramin Bahrani (director/screenplay); Adarsh Go...
# 2    Doug Liman (director); Steven Knight (screenpl...
# 3    Simon Stone (director); Moira Buffini (screenp...
# 4    Mikael Håfström (director); Rob Yescombe, Rowa...
# ..                                                 ...
# 353  Joel Coen (director/screenplay); Denzel Washin...
# 354  Denzel Washington (director); Virgil Williams ...
# 355  Erwin brothers (directors); Jon Erwin, David A...
# 356  Apichatpong Weerasethakul (director/acreenplay...
# 357                                                NaN
#
#                               genres
# 0                  Horror Action War
# 1                              Drama
# 2                 Comedy Crime Drama
# 3                      Drama History
# 4    Thriller Action Science Fiction
# ..                               ...
# 353                        Drama War
# 354                    Drama Romance
# 355                            Drama
# 356            Drama Fantasy Mystery
# 357                           Comedy
#
# [358 rows x 3 columns]

# %%
df_2021['director_name'] = df_2021['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_2021 = df_2021.dropna(how='any')

# %%
df_2021['actor_1_name'] = df_2021['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_2021['actor_2_name'] = df_2021['Cast and crew'].map(lambda x: get_actor2(x))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_2021['actor_3_name'] = df_2021['Cast and crew'].map(lambda x: get_actor3(x))
df_2021 = df_2021.rename(columns={'Title':'movie_title'})
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
new_df21 = df_2021.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]
new_df21['actor_2_name'] = new_df21['actor_2_name'].replace(np.nan, 'unknown')
new_df21['actor_3_name'] = new_df21['actor_3_name'].replace(np.nan, 'unknown')
new_df21['movie_title'] = new_df21['movie_title'].str.lower()
new_df21['comb'] = new_df21['actor_1_name'] + ' ' + new_df21['actor_2_name'] + ' '+ new_df21['actor_3_name'] + ' '+ new_df21['director_name'] +' ' + new_df21['genres']
new_df21
# Out:
#                                          director_name  \
# 0                                       Roseanne Liang
# 1                                        Ramin Bahrani
# 2                                           Doug Liman
# 3                                          Simon Stone
# 4                                      Mikael Håfström
# ..                                                 ...
# 352                                     Matthew Vaughn
# 353                                          Joel Coen
# 354                                  Denzel Washington
# 355                                     Erwin brothers
# 356  Apichatpong Weerasethakul (director/acreenplay...
#
#                                           actor_1_name       actor_2_name  \
# 0                                   Chloë Grace Moretz  Taylor John Smith
# 1                                        Adarsh Gourav      Rajkummar Rao
# 2                                        Anne Hathaway   Chiwetel Ejiofor
# 3                                       Carey Mulligan      Ralph Fiennes
# 4                                       Anthony Mackie       Damson Idris
# ..                                                 ...                ...
# 352                                      Ralph Fiennes     Gemma Arterton
# 353                                  Denzel Washington  Frances McDormand
# 354                                  Michael B. Jordan       Chanté Adams
# 355                                       Zachary Levi        Anna Paquin
# 356  Apichatpong Weerasethakul (director/acreenplay...         Elkin Díaz
#
#               actor_3_name                           genres  \
# 0             Beulah Koale                Horror Action War
# 1    Priyanka Chopra Jonas                            Drama
# 2         Stephen Merchant               Comedy Crime Drama
# 3               Lily James                    Drama History
# 4            Emily Beecham  Thriller Action Science Fiction
# ..                     ...                              ...
# 352             Rhys Ifans    Action Adventure Thriller War
# 353          Bertie Carvel                        Drama War
# 354        Jalon Christian                    Drama Romance
# 355           Dennis Quaid                            Drama
# 356         Jeanne Balibar            Drama Fantasy Mystery
#
#                 movie_title                                               comb
# 0       shadow in the cloud  Chloë Grace Moretz Taylor John Smith Beulah Ko...
# 1           the white tiger  Adarsh Gourav Rajkummar Rao Priyanka Chopra Jo...
# 2               locked down  Anne Hathaway Chiwetel Ejiofor Stephen Merchan...
# 3                   the dig  Carey Mulligan Ralph Fiennes Lily James Simon ...
# 4          outside the wire  Anthony Mackie Damson Idris Emily Beecham Mika...
# ..                      ...                                                ...
# 352          the king's man  Ralph Fiennes Gemma Arterton Rhys Ifans Matthe...
# 353  the tragedy of macbeth  Denzel Washington Frances McDormand Bertie Car...
# 354    a journal for jordan  Michael B. Jordan Chanté Adams Jalon Christian...
# 355       american underdog  Zachary Levi Anna Paquin Dennis Quaid Erwin br...
# 356                 memoria  Apichatpong Weerasethakul (director/acreenplay...
#
# [356 rows x 7 columns]

# %%
my_df = new_df20.append(new_df21,ignore_index=True)
my_df
# Out:
#                                          director_name  \
# 0                                        Nicolas Pesce
# 1                                       William Eubank
# 2                                        Miguel Arteta
# 3                                            Jon Avnet
# 4                                       Anthony Jerjen
# ..                                                 ...
# 625                                     Matthew Vaughn
# 626                                          Joel Coen
# 627                                  Denzel Washington
# 628                                     Erwin brothers
# 629  Apichatpong Weerasethakul (director/acreenplay...
#
#                                           actor_1_name       actor_2_name  \
# 0                                   Andrea Riseborough      Demián Bichir
# 1                                      Kristen Stewart     Vincent Cassel
# 2                                      Tiffany Haddish         Rose Byrne
# 3                                         Richard Gere     Peter Dinklage
# 4                                        Josh Hartnett  Margarita Levieva
# ..                                                 ...                ...
# 625                                      Ralph Fiennes     Gemma Arterton
# 626                                  Denzel Washington  Frances McDormand
# 627                                  Michael B. Jordan       Chanté Adams
# 628                                       Zachary Levi        Anna Paquin
# 629  Apichatpong Weerasethakul (director/acreenplay...         Elkin Díaz
#
#         actor_3_name                                  genres  \
# 0           John Cho                 Horror Mystery Thriller
# 1    Jessica Henwick  Action Horror Science Fiction Thriller
# 2        Salma Hayek                                  Comedy
# 3     Walton Goggins                                   Drama
# 4     Chandler Riggs                    Crime Thriller Drama
# ..               ...                                     ...
# 625       Rhys Ifans           Action Adventure Thriller War
# 626    Bertie Carvel                               Drama War
# 627  Jalon Christian                           Drama Romance
# 628     Dennis Quaid                                   Drama
# 629   Jeanne Balibar                   Drama Fantasy Mystery
#
#                 movie_title                                               comb
# 0                the grudge  Andrea Riseborough Demián Bichir John Cho Nico...
# 1                underwater  Kristen Stewart Vincent Cassel Jessica Henwick...
# 2               like a boss  Tiffany Haddish Rose Byrne Salma Hayek Miguel ...
# 3             three christs  Richard Gere Peter Dinklage Walton Goggins Jon...
# 4         inherit the viper  Josh Hartnett Margarita Levieva Chandler Riggs...
# ..                      ...                                                ...
# 625          the king's man  Ralph Fiennes Gemma Arterton Rhys Ifans Matthe...
# 626  the tragedy of macbeth  Denzel Washington Frances McDormand Bertie Car...
# 627    a journal for jordan  Michael B. Jordan Chanté Adams Jalon Christian...
# 628       american underdog  Zachary Levi Anna Paquin Dennis Quaid Erwin br...
# 629                 memoria  Apichatpong Weerasethakul (director/acreenplay...
#
# [630 rows x 7 columns]

# %%
old_df = pd.read_csv('./movie.csv')
old_df
# Out:
#          director_name     actor_1_name    actor_2_name     actor_3_name  \
# 0        John Lasseter        Tom Hanks       Tim Allen      Don Rickles
# 1         Joe Johnston   Robin Williams   Jonathan Hyde    Kirsten Dunst
# 2        Howard Deutch   Walter Matthau     Jack Lemmon      Ann-Margret
# 3      Forest Whitaker  Whitney Houston  Angela Bassett   Loretta Devine
# 4        Charles Shyer     Steve Martin    Diane Keaton     Martin Short
# ...                ...              ...             ...              ...
# 36336         Ben Rock       Monty Bane     Lucy Butler    David Grammer
# 36337    Aaron Osborne       Lisa Boyle       Kena Land    Zaneta Polard
# 36338       John Irvin   Patrick Bergin     Uma Thurman  David Morrissey
# 36339         Lav Diaz     Angel Aquino     Perry Dizon    Hazel Orencio
# 36340   Mark L. Lester    Erika Eleniak    Adam Baldwin    Julie du Page
#
#                          genres                  movie_title  \
# 0       Animation Comedy Family                    toy story
# 1      Adventure Fantasy Family                      jumanji
# 2                Romance Comedy             grumpier old men
# 3          Comedy Drama Romance            waiting to exhale
# 4                        Comedy  father of the bride part ii
# ...                         ...                          ...
# 36336                    Horror          the burkittsville 7
# 36337                    Sci-Fi              caged heat 3000
# 36338      Drama Action Romance                   robin hood
# 36339                     Drama          century of birthing
# 36340     Action Drama Thriller                     betrayal
#
#                                                     comb
# 0      Tom Hanks Tim Allen Don Rickles John Lasseter ...
# 1      Robin Williams Jonathan Hyde Kirsten Dunst Joe...
# 2      Walter Matthau Jack Lemmon Ann-Margret Howard ...
# 3      Whitney Houston Angela Bassett Loretta Devine ...
# 4      Steve Martin Diane Keaton Martin Short Charles...
# ...                                                  ...
# 36336  Monty Bane Lucy Butler David Grammer Ben Rock ...
# 36337  Lisa Boyle Kena Land Zaneta Polard Aaron Osbor...
# 36338  Patrick Bergin Uma Thurman David Morrissey Joh...
# 36339  Angel Aquino Perry Dizon Hazel Orencio Lav Dia...
# 36340  Erika Eleniak Adam Baldwin Julie du Page Mark ...
#
# [36341 rows x 7 columns]

# %%
final_df = old_df.append(my_df,ignore_index=True)
final_df
# Out:
#                                            director_name  \
# 0                                          John Lasseter
# 1                                           Joe Johnston
# 2                                          Howard Deutch
# 3                                        Forest Whitaker
# 4                                          Charles Shyer
# ...                                                  ...
# 36966                                     Matthew Vaughn
# 36967                                          Joel Coen
# 36968                                  Denzel Washington
# 36969                                     Erwin brothers
# 36970  Apichatpong Weerasethakul (director/acreenplay...
#
#                                             actor_1_name       actor_2_name  \
# 0                                              Tom Hanks          Tim Allen
# 1                                         Robin Williams      Jonathan Hyde
# 2                                         Walter Matthau        Jack Lemmon
# 3                                        Whitney Houston     Angela Bassett
# 4                                           Steve Martin       Diane Keaton
# ...                                                  ...                ...
# 36966                                      Ralph Fiennes     Gemma Arterton
# 36967                                  Denzel Washington  Frances McDormand
# 36968                                  Michael B. Jordan       Chanté Adams
# 36969                                       Zachary Levi        Anna Paquin
# 36970  Apichatpong Weerasethakul (director/acreenplay...         Elkin Díaz
#
#           actor_3_name                         genres  \
# 0          Don Rickles        Animation Comedy Family
# 1        Kirsten Dunst       Adventure Fantasy Family
# 2          Ann-Margret                 Romance Comedy
# 3       Loretta Devine           Comedy Drama Romance
# 4         Martin Short                         Comedy
# ...                ...                            ...
# 36966       Rhys Ifans  Action Adventure Thriller War
# 36967    Bertie Carvel                      Drama War
# 36968  Jalon Christian                  Drama Romance
# 36969     Dennis Quaid                          Drama
# 36970   Jeanne Balibar          Drama Fantasy Mystery
#
#                        movie_title  \
# 0                        toy story
# 1                          jumanji
# 2                 grumpier old men
# 3                waiting to exhale
# 4      father of the bride part ii
# ...                            ...
# 36966               the king's man
# 36967       the tragedy of macbeth
# 36968         a journal for jordan
# 36969            american underdog
# 36970                      memoria
#
#                                                     comb
# 0      Tom Hanks Tim Allen Don Rickles John Lasseter ...
# 1      Robin Williams Jonathan Hyde Kirsten Dunst Joe...
# 2      Walter Matthau Jack Lemmon Ann-Margret Howard ...
# 3      Whitney Houston Angela Bassett Loretta Devine ...
# 4      Steve Martin Diane Keaton Martin Short Charles...
# ...                                                  ...
# 36966  Ralph Fiennes Gemma Arterton Rhys Ifans Matthe...
# 36967  Denzel Washington Frances McDormand Bertie Car...
# 36968  Michael B. Jordan Chanté Adams Jalon Christian...
# 36969  Zachary Levi Anna Paquin Dennis Quaid Erwin br...
# 36970  Apichatpong Weerasethakul (director/acreenplay...
#
# [36971 rows x 7 columns]

# %%
final_df.isna().sum()
final_df = final_df.dropna(how='any')

# %%
final_df.to_csv('./datasets/final_data.csv',index=False)

# %% [markdown]
# ### Movies from 2019

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2019"
df1 = pd.read_html(link, header=0)[3]
df2 = pd.read_html(link, header=0)[4]
df3 = pd.read_html(link, header=0)[5]
df4 = pd.read_html(link, header=0)[6]
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
df
# Out:
#       Opening  Opening.1                Title  \
# 0       APRIL        5.0              Shazam!
# 1       APRIL        5.0         Pet Sematary
# 2       APRIL        5.0  The Best of Enemies
# 3       APRIL        5.0            High Life
# 4       APRIL        5.0        Unicorn Store
# ..        ...        ...                  ...
# 188  DECEMBER       25.0    Spies in Disguise
# 189  DECEMBER       25.0         Little Women
# 190  DECEMBER       25.0                 1917
# 191  DECEMBER       25.0           Just Mercy
# 192  DECEMBER       27.0             Clemency
#
#                                     Production company  \
# 0    Warner Bros. Pictures / New Line Cinema / DC F...
# 1                                   Paramount Pictures
# 2                                    STX Entertainment
# 3                    A24 / Arte / ZDF / Canal+ / Ciné+
# 4                                              Netflix
# ..                                                 ...
# 188  20th Century Fox / Blue Sky Studios / Chernin ...
# 189            Columbia Pictures / Regency Enterprises
# 190           Universal Pictures / DreamWorks Pictures
# 191          Warner Bros. Pictures / Participant Media
# 192                                               Neon
#
#                                          Cast and crew   Ref. Unnamed: 0  \
# 0    David F. Sandberg (director); Henry Gayden (sc...   [51]        NaN
# 1    Kevin Kolsch, Dennis Widmyer (directors); Jeff...   [52]        NaN
# 2    Robin Bissell (director/screenplay); Taraji P....   [53]        NaN
# 3    Claire Denis (director/screenplay); Jean-Pol F...   [54]        NaN
# 4    Brie Larson (director); Samantha McIntyre (scr...    NaN        NaN
# ..                                                 ...    ...        ...
# 188  Nick Bruno, Troy Quane (directors); Brad Copel...  [132]        NaN
# 189  Greta Gerwig (director/screenplay); Saoirse Ro...  [221]        NaN
# 190  Sam Mendes (director/screenplay); Krysty Wilso...  [222]        NaN
# 191  Destin Daniel Cretton (director/screenplay), A...  [223]        NaN
# 192  Chinonye Chukwu (director/screenplay); Alfre W...  [224]        NaN
#
#     Wikimedia Commons has media related to Films of the United States, 2019.
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 188                                                NaN
# 189                                                NaN
# 190                                                NaN
# 191                                                NaN
# 192                                                NaN
#
# [193 rows x 8 columns]

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))
df_2019 = df[['Title','Cast and crew','genres']]
df_2019
# Out:
#                    Title                                      Cast and crew  \
# 0                Shazam!  David F. Sandberg (director); Henry Gayden (sc...
# 1           Pet Sematary  Kevin Kolsch, Dennis Widmyer (directors); Jeff...
# 2    The Best of Enemies  Robin Bissell (director/screenplay); Taraji P....
# 3              High Life  Claire Denis (director/screenplay); Jean-Pol F...
# 4          Unicorn Store  Brie Larson (director); Samantha McIntyre (scr...
# ..                   ...                                                ...
# 188    Spies in Disguise  Nick Bruno, Troy Quane (directors); Brad Copel...
# 189         Little Women  Greta Gerwig (director/screenplay); Saoirse Ro...
# 190                 1917  Sam Mendes (director/screenplay); Krysty Wilso...
# 191           Just Mercy  Destin Daniel Cretton (director/screenplay), A...
# 192             Clemency  Chinonye Chukwu (director/screenplay); Alfre W...
#
#                                        genres
# 0                       Action Comedy Fantasy
# 1                                      Horror
# 2                               Drama History
# 3      Science Fiction Drama Mystery Thriller
# 4                        Fantasy Drama Comedy
# ..                                        ...
# 188  Animation Action Adventure Comedy Family
# 189                             Drama Romance
# 190                 War Drama Action Thriller
# 191                       Drama Crime History
# 192                                     Drama
#
# [193 rows x 3 columns]

# %%
df_2019['director_name'] = df_2019['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_2019['actor_1_name'] = df_2019['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_2019['actor_2_name'] = df_2019['Cast and crew'].map(lambda x: get_actor2(x))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_2019['actor_3_name'] = df_2019['Cast and crew'].map(lambda x: get_actor3(x))
df_2019 = df_2019.rename(columns={'Title':'movie_title'})
new_df19 = df_2019.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
new_df19['actor_2_name'] = new_df19['actor_2_name'].replace(np.nan, 'unknown')
new_df19['actor_3_name'] = new_df19['actor_3_name'].replace(np.nan, 'unknown')
new_df19['movie_title'] = new_df19['movie_title'].str.lower()
new_df19['comb'] = new_df19['actor_1_name'] + ' ' + new_df19['actor_2_name'] + ' '+ new_df19['actor_3_name'] + ' '+ new_df19['director_name'] +' ' + new_df19['genres']
new_df19
# Out:
#                     director_name       actor_1_name          actor_2_name  \
# 0               David F. Sandberg       Zachary Levi           Asher Angel
# 1    Kevin Kolsch, Dennis Widmyer       Jason Clarke           Amy Seimetz
# 2                   Robin Bissell   Taraji P. Henson          Sam Rockwell
# 3                    Claire Denis   Robert Pattinson      Juliette Binoche
# 4                     Brie Larson        Brie Larson     Samuel L. Jackson
# ..                            ...                ...                   ...
# 188        Nick Bruno, Troy Quane         Will Smith           Tom Holland
# 189                  Greta Gerwig      Saoirse Ronan           Emma Watson
# 190                    Sam Mendes      George MacKay  Dean-Charles Chapman
# 191         Destin Daniel Cretton  Michael B. Jordan            Jamie Foxx
# 192               Chinonye Chukwu      Alfre Woodard        Wendell Pierce
#
#        actor_3_name                                    genres  \
# 0       Mark Strong                     Action Comedy Fantasy
# 1      John Lithgow                                    Horror
# 2           unknown                             Drama History
# 3    André Benjamin    Science Fiction Drama Mystery Thriller
# 4       Joan Cusack                      Fantasy Drama Comedy
# ..              ...                                       ...
# 188   Rashida Jones  Animation Action Adventure Comedy Family
# 189   Florence Pugh                             Drama Romance
# 190     Mark Strong                 War Drama Action Thriller
# 191     Brie Larson                       Drama Crime History
# 192     Aldis Hodge                                     Drama
#
#              movie_title                                               comb
# 0                shazam!  Zachary Levi Asher Angel Mark Strong David F. ...
# 1           pet sematary  Jason Clarke Amy Seimetz John Lithgow Kevin Ko...
# 2    the best of enemies  Taraji P. Henson Sam Rockwell unknown Robin Bi...
# 3              high life  Robert Pattinson Juliette Binoche André Benjam...
# 4          unicorn store  Brie Larson Samuel L. Jackson Joan Cusack Brie...
# ..                   ...                                                ...
# 188    spies in disguise  Will Smith Tom Holland Rashida Jones Nick Brun...
# 189         little women  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 190                 1917  George MacKay Dean-Charles Chapman Mark Strong...
# 191           just mercy  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 192             clemency  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
#
# [193 rows x 7 columns]

# %%
final_df = final_df.append(new_df19,ignore_index=True)
final_df
# Out:
#                 director_name       actor_1_name          actor_2_name  \
# 0               John Lasseter          Tom Hanks             Tim Allen
# 1                Joe Johnston     Robin Williams         Jonathan Hyde
# 2               Howard Deutch     Walter Matthau           Jack Lemmon
# 3             Forest Whitaker    Whitney Houston        Angela Bassett
# 4               Charles Shyer       Steve Martin          Diane Keaton
# ...                       ...                ...                   ...
# 37158  Nick Bruno, Troy Quane         Will Smith           Tom Holland
# 37159            Greta Gerwig      Saoirse Ronan           Emma Watson
# 37160              Sam Mendes      George MacKay  Dean-Charles Chapman
# 37161   Destin Daniel Cretton  Michael B. Jordan            Jamie Foxx
# 37162         Chinonye Chukwu      Alfre Woodard        Wendell Pierce
#
#          actor_3_name                                    genres  \
# 0         Don Rickles                   Animation Comedy Family
# 1       Kirsten Dunst                  Adventure Fantasy Family
# 2         Ann-Margret                            Romance Comedy
# 3      Loretta Devine                      Comedy Drama Romance
# 4        Martin Short                                    Comedy
# ...               ...                                       ...
# 37158   Rashida Jones  Animation Action Adventure Comedy Family
# 37159   Florence Pugh                             Drama Romance
# 37160     Mark Strong                 War Drama Action Thriller
# 37161     Brie Larson                       Drama Crime History
# 37162     Aldis Hodge                                     Drama
#
#                        movie_title  \
# 0                        toy story
# 1                          jumanji
# 2                 grumpier old men
# 3                waiting to exhale
# 4      father of the bride part ii
# ...                            ...
# 37158            spies in disguise
# 37159                 little women
# 37160                         1917
# 37161                   just mercy
# 37162                     clemency
#
#                                                     comb
# 0      Tom Hanks Tim Allen Don Rickles John Lasseter ...
# 1      Robin Williams Jonathan Hyde Kirsten Dunst Joe...
# 2      Walter Matthau Jack Lemmon Ann-Margret Howard ...
# 3      Whitney Houston Angela Bassett Loretta Devine ...
# 4      Steve Martin Diane Keaton Martin Short Charles...
# ...                                                  ...
# 37158  Will Smith Tom Holland Rashida Jones Nick Brun...
# 37159  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 37160  George MacKay Dean-Charles Chapman Mark Strong...
# 37161  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 37162  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
#
# [37163 rows x 7 columns]

# %% [markdown]
# ### Movies from 2018

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2018"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
df
# Out:
#       Opening  Opening.1                       Title  \
# 0     JANUARY          5     Insidious: The Last Key
# 1     JANUARY          5            The Strange Ones
# 2     JANUARY          5                    Stratton
# 3     JANUARY         10               Sweet Country
# 4     JANUARY         12                The Commuter
# ..        ...        ...                         ...
# 267  DECEMBER         25             Holmes & Watson
# 268  DECEMBER         25                        Vice
# 269  DECEMBER         25         On the Basis of Sex
# 270  DECEMBER         25                   Destroyer
# 271  DECEMBER         28  Black Mirror: Bandersnatch
#
#                                     Production company  \
# 0    Universal Pictures / Blumhouse Productions / S...
# 1                               Vertical Entertainment
# 2                                    Momentum Pictures
# 3                                 Samuel Goldwyn Films
# 4        Lionsgate / StudioCanal / The Picture Company
# ..                                                 ...
# 267       Columbia Pictures / Gary Sanchez Productions
# 268          Annapurna Pictures / Plan B Entertainment
# 269                                     Focus Features
# 270                                 Annapurna Pictures
# 271                                            Netflix
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Lauren Wolkstein (director); Christopher Radcl...
# 2    Simon West (director); Duncan Falconer, Warren...
# 3    Warwick Thornton (director); David Tranter, St...
# 4    Jaume Collet-Serra (director); Byron Willinger...
# ..                                                 ...
# 267  Etan Cohen (director/screenplay); Will Ferrell...
# 268  Adam McKay (director/screenplay); Christian Ba...
# 269  Mimi Leder (director); Daniel Stiepleman (scre...
# 270  Karyn Kusama (director); Phil Hay, Matt Manfre...
# 271  David Slade (director); Charlie Brooker (scree...
#
#     .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Ref.  \
# 0                                                  [2]
# 1                                                  [3]
# 2                                                  [4]
# 3                                                  [5]
# 4                                                  [6]
# ..                                                 ...
# 267                                                NaN
# 268                                                NaN
# 269                                                NaN
# 270                                                NaN
# 271                                                NaN
#
#       Ref.
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ..     ...
# 267  [164]
# 268  [137]
# 269  [228]
# 270  [260]
# 271  [261]
#
# [272 rows x 7 columns]

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))
df_2018 = df[['Title','Cast and crew','genres']]
df_2018
# Out:
#                           Title  \
# 0       Insidious: The Last Key
# 1              The Strange Ones
# 2                      Stratton
# 3                 Sweet Country
# 4                  The Commuter
# ..                          ...
# 267             Holmes & Watson
# 268                        Vice
# 269         On the Basis of Sex
# 270                   Destroyer
# 271  Black Mirror: Bandersnatch
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Lauren Wolkstein (director); Christopher Radcl...
# 2    Simon West (director); Duncan Falconer, Warren...
# 3    Warwick Thornton (director); David Tranter, St...
# 4    Jaume Collet-Serra (director); Byron Willinger...
# ..                                                 ...
# 267  Etan Cohen (director/screenplay); Will Ferrell...
# 268  Adam McKay (director/screenplay); Christian Ba...
# 269  Mimi Leder (director); Daniel Stiepleman (scre...
# 270  Karyn Kusama (director); Phil Hay, Matt Manfre...
# 271  David Slade (director); Charlie Brooker (scree...
#
#                                               genres
# 0                            Horror Mystery Thriller
# 1                                     Thriller Drama
# 2                                    Action Thriller
# 3                              Drama History Western
# 4                            Action Thriller Mystery
# ..                                               ...
# 267                   Mystery Adventure Comedy Crime
# 268                             Drama History Comedy
# 269                                    Drama History
# 270                      Thriller Crime Drama Action
# 271  Science Fiction Mystery Drama Thriller TV Movie
#
# [272 rows x 3 columns]

# %%
df_2018['director_name'] = df_2018['Cast and crew'].map(lambda x: get_director(x))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_2018['actor_1_name'] = df_2018['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_2018['actor_2_name'] = df_2018['Cast and crew'].map(lambda x: get_actor2(x))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_2018['actor_3_name'] = df_2018['Cast and crew'].map(lambda x: get_actor3(x))
df_2018
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                           Title  \
# 0       Insidious: The Last Key
# 1              The Strange Ones
# 2                      Stratton
# 3                 Sweet Country
# 4                  The Commuter
# ..                          ...
# 267             Holmes & Watson
# 268                        Vice
# 269         On the Basis of Sex
# 270                   Destroyer
# 271  Black Mirror: Bandersnatch
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Lauren Wolkstein (director); Christopher Radcl...
# 2    Simon West (director); Duncan Falconer, Warren...
# 3    Warwick Thornton (director); David Tranter, St...
# 4    Jaume Collet-Serra (director); Byron Willinger...
# ..                                                 ...
# 267  Etan Cohen (director/screenplay); Will Ferrell...
# 268  Adam McKay (director/screenplay); Christian Ba...
# 269  Mimi Leder (director); Daniel Stiepleman (scre...
# 270  Karyn Kusama (director); Phil Hay, Matt Manfre...
# 271  David Slade (director); Charlie Brooker (scree...
#
#                                               genres       director_name  \
# 0                            Horror Mystery Thriller        Adam Robitel
# 1                                     Thriller Drama    Lauren Wolkstein
# 2                                    Action Thriller          Simon West
# 3                              Drama History Western    Warwick Thornton
# 4                            Action Thriller Mystery  Jaume Collet-Serra
# ..                                               ...                 ...
# 267                   Mystery Adventure Comedy Crime          Etan Cohen
# 268                             Drama History Comedy          Adam McKay
# 269                                    Drama History          Mimi Leder
# 270                      Thriller Crime Drama Action        Karyn Kusama
# 271  Science Fiction Mystery Drama Thriller TV Movie         David Slade
#
#         actor_1_name            actor_2_name    actor_3_name
# 0          Lin Shaye           Angus Sampson  Leigh Whannell
# 1      Alex Pettyfer  James Freedson-Jackson   Emily Althaus
# 2     Dominic Cooper          Austin Stowell      Gemma Chan
# 3        Bryan Brown               Sam Neill             NaN
# 4        Liam Neeson            Vera Farmiga  Patrick Wilson
# ..               ...                     ...             ...
# 267     Will Ferrell          John C. Reilly    Rebecca Hall
# 268   Christian Bale               Amy Adams    Steve Carell
# 269   Felicity Jones            Armie Hammer  Justin Theroux
# 270    Nicole Kidman          Sebastian Stan    Toby Kebbell
# 271  Fionn Whitehead            Will Poulter   Asim Chaudhry
#
# [272 rows x 7 columns]

# %%
df_2018 = df_2018.rename(columns={'Title':'movie_title'})
new_df18 = df_2018.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]
new_df18
# Out:
#           director_name     actor_1_name            actor_2_name  \
# 0          Adam Robitel        Lin Shaye           Angus Sampson
# 1      Lauren Wolkstein    Alex Pettyfer  James Freedson-Jackson
# 2            Simon West   Dominic Cooper          Austin Stowell
# 3      Warwick Thornton      Bryan Brown               Sam Neill
# 4    Jaume Collet-Serra      Liam Neeson            Vera Farmiga
# ..                  ...              ...                     ...
# 267          Etan Cohen     Will Ferrell          John C. Reilly
# 268          Adam McKay   Christian Bale               Amy Adams
# 269          Mimi Leder   Felicity Jones            Armie Hammer
# 270        Karyn Kusama    Nicole Kidman          Sebastian Stan
# 271         David Slade  Fionn Whitehead            Will Poulter
#
#        actor_3_name                                           genres  \
# 0    Leigh Whannell                          Horror Mystery Thriller
# 1     Emily Althaus                                   Thriller Drama
# 2        Gemma Chan                                  Action Thriller
# 3               NaN                            Drama History Western
# 4    Patrick Wilson                          Action Thriller Mystery
# ..              ...                                              ...
# 267    Rebecca Hall                   Mystery Adventure Comedy Crime
# 268    Steve Carell                             Drama History Comedy
# 269  Justin Theroux                                    Drama History
# 270    Toby Kebbell                      Thriller Crime Drama Action
# 271   Asim Chaudhry  Science Fiction Mystery Drama Thriller TV Movie
#
#                     movie_title
# 0       Insidious: The Last Key
# 1              The Strange Ones
# 2                      Stratton
# 3                 Sweet Country
# 4                  The Commuter
# ..                          ...
# 267             Holmes & Watson
# 268                        Vice
# 269         On the Basis of Sex
# 270                   Destroyer
# 271  Black Mirror: Bandersnatch
#
# [272 rows x 6 columns]

# %%
new_df18['actor_2_name'] = new_df18['actor_2_name'].replace(np.nan, 'unknown')
new_df18['actor_3_name'] = new_df18['actor_3_name'].replace(np.nan, 'unknown')
new_df18['movie_title'] = new_df18['movie_title'].str.lower()
new_df18['comb'] = new_df18['actor_1_name'] + ' ' + new_df18['actor_2_name'] + ' '+ new_df18['actor_3_name'] + ' '+ new_df18['director_name'] +' ' + new_df18['genres']
new_df18
# Out:
#           director_name     actor_1_name            actor_2_name  \
# 0          Adam Robitel        Lin Shaye           Angus Sampson
# 1      Lauren Wolkstein    Alex Pettyfer  James Freedson-Jackson
# 2            Simon West   Dominic Cooper          Austin Stowell
# 3      Warwick Thornton      Bryan Brown               Sam Neill
# 4    Jaume Collet-Serra      Liam Neeson            Vera Farmiga
# ..                  ...              ...                     ...
# 267          Etan Cohen     Will Ferrell          John C. Reilly
# 268          Adam McKay   Christian Bale               Amy Adams
# 269          Mimi Leder   Felicity Jones            Armie Hammer
# 270        Karyn Kusama    Nicole Kidman          Sebastian Stan
# 271         David Slade  Fionn Whitehead            Will Poulter
#
#        actor_3_name                                           genres  \
# 0    Leigh Whannell                          Horror Mystery Thriller
# 1     Emily Althaus                                   Thriller Drama
# 2        Gemma Chan                                  Action Thriller
# 3           unknown                            Drama History Western
# 4    Patrick Wilson                          Action Thriller Mystery
# ..              ...                                              ...
# 267    Rebecca Hall                   Mystery Adventure Comedy Crime
# 268    Steve Carell                             Drama History Comedy
# 269  Justin Theroux                                    Drama History
# 270    Toby Kebbell                      Thriller Crime Drama Action
# 271   Asim Chaudhry  Science Fiction Mystery Drama Thriller TV Movie
#
#                     movie_title  \
# 0       insidious: the last key
# 1              the strange ones
# 2                      stratton
# 3                 sweet country
# 4                  the commuter
# ..                          ...
# 267             holmes & watson
# 268                        vice
# 269         on the basis of sex
# 270                   destroyer
# 271  black mirror: bandersnatch
#
#                                                   comb
# 0    Lin Shaye Angus Sampson Leigh Whannell Adam Ro...
# 1    Alex Pettyfer James Freedson-Jackson Emily Alt...
# 2    Dominic Cooper Austin Stowell Gemma Chan Simon...
# 3    Bryan Brown Sam Neill unknown Warwick Thornton...
# 4    Liam Neeson Vera Farmiga Patrick Wilson Jaume ...
# ..                                                 ...
# 267  Will Ferrell John C. Reilly Rebecca Hall Etan ...
# 268  Christian Bale Amy Adams Steve Carell Adam McK...
# 269  Felicity Jones Armie Hammer Justin Theroux Mim...
# 270  Nicole Kidman Sebastian Stan Toby Kebbell Kary...
# 271  Fionn Whitehead Will Poulter Asim Chaudhry Dav...
#
# [272 rows x 7 columns]

# %%
final_df = final_df.append(new_df18,ignore_index=True)
final_df
# Out:
#          director_name     actor_1_name    actor_2_name    actor_3_name  \
# 0        John Lasseter        Tom Hanks       Tim Allen     Don Rickles
# 1         Joe Johnston   Robin Williams   Jonathan Hyde   Kirsten Dunst
# 2        Howard Deutch   Walter Matthau     Jack Lemmon     Ann-Margret
# 3      Forest Whitaker  Whitney Houston  Angela Bassett  Loretta Devine
# 4        Charles Shyer     Steve Martin    Diane Keaton    Martin Short
# ...                ...              ...             ...             ...
# 37430       Etan Cohen     Will Ferrell  John C. Reilly    Rebecca Hall
# 37431       Adam McKay   Christian Bale       Amy Adams    Steve Carell
# 37432       Mimi Leder   Felicity Jones    Armie Hammer  Justin Theroux
# 37433     Karyn Kusama    Nicole Kidman  Sebastian Stan    Toby Kebbell
# 37434      David Slade  Fionn Whitehead    Will Poulter   Asim Chaudhry
#
#                                                 genres  \
# 0                              Animation Comedy Family
# 1                             Adventure Fantasy Family
# 2                                       Romance Comedy
# 3                                 Comedy Drama Romance
# 4                                               Comedy
# ...                                                ...
# 37430                   Mystery Adventure Comedy Crime
# 37431                             Drama History Comedy
# 37432                                    Drama History
# 37433                      Thriller Crime Drama Action
# 37434  Science Fiction Mystery Drama Thriller TV Movie
#
#                        movie_title  \
# 0                        toy story
# 1                          jumanji
# 2                 grumpier old men
# 3                waiting to exhale
# 4      father of the bride part ii
# ...                            ...
# 37430              holmes & watson
# 37431                         vice
# 37432          on the basis of sex
# 37433                    destroyer
# 37434   black mirror: bandersnatch
#
#                                                     comb
# 0      Tom Hanks Tim Allen Don Rickles John Lasseter ...
# 1      Robin Williams Jonathan Hyde Kirsten Dunst Joe...
# 2      Walter Matthau Jack Lemmon Ann-Margret Howard ...
# 3      Whitney Houston Angela Bassett Loretta Devine ...
# 4      Steve Martin Diane Keaton Martin Short Charles...
# ...                                                  ...
# 37430  Will Ferrell John C. Reilly Rebecca Hall Etan ...
# 37431  Christian Bale Amy Adams Steve Carell Adam McK...
# 37432  Felicity Jones Armie Hammer Justin Theroux Mim...
# 37433  Nicole Kidman Sebastian Stan Toby Kebbell Kary...
# 37434  Fionn Whitehead Will Poulter Asim Chaudhry Dav...
#
# [37435 rows x 7 columns]

# %%
final_df = final_df.dropna(how='any')
final_df.to_csv('./datasets/final_data.csv',index=False)

# %% [markdown]
# ### Movies from 2022

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2022"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
df
# Out:
#      Rank                         Title     Distributor Domestic gross  \
# 0     1.0                   The Batman*    Warner Bros.   $300,014,069
# 1     2.0                    Uncharted*            Sony   $125,722,674
# 2     3.0                       Scream*       Paramount    $81,391,774
# 3     4.0              Jackass Forever*       Paramount    $57,265,660
# 4     5.0                          Dog*  United Artists    $54,127,363
# ..    ...                           ...             ...            ...
# 130   NaN                       Distant             NaN            NaN
# 131   NaN           Don't Worry Darling             NaN            NaN
# 132   NaN  Puss in Boots: The Last Wish             NaN            NaN
# 133   NaN                          Bros             NaN            NaN
# 134   NaN                           NaN             NaN            NaN
#
#        Opening  Opening.1                                 Production company  \
# 0          NaN        NaN                                                NaN
# 1          NaN        NaN                                                NaN
# 2          NaN        NaN                                                NaN
# 3          NaN        NaN                                                NaN
# 4          NaN        NaN                                                NaN
# ..         ...        ...                                                ...
# 130  SEPTEMBER       16.0  Universal Pictures / DreamWorks Pictures / Amb...
# 131  SEPTEMBER       23.0            Warner Bros. Pictures / New Line Cinema
# 132  SEPTEMBER       23.0          Universal Pictures / DreamWorks Animation
# 133  SEPTEMBER       30.0            Universal Pictures / Apatow Productions
# 134  SEPTEMBER        NaN                                                NaN
#
#                                          Cast and crew  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 130  Josh Gordon & Will Speck (directors); Spenser ...
# 131  Olivia Wilde (director); Katie Silberman, Care...
# 132  Joel Crawford (director); Antonio Banderas, Sa...
# 133  Nicholas Stoller (director/screenplay); Billy ...
# 134                                                NaN
#
#     .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Ref.  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 130                                                NaN
# 131                                                NaN
# 132                                                NaN
# 133                                                NaN
# 134                                                NaN
#
#       Ref.
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ..     ...
# 130  [111]
# 131  [112]
# 132  [113]
# 133  [114]
# 134    NaN
#
# [135 rows x 10 columns]

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))
df_2022 = df[['Title','Cast and crew','genres']]
df_2022
# Out:
#                             Title  \
# 0                     The Batman*
# 1                      Uncharted*
# 2                         Scream*
# 3                Jackass Forever*
# 4                            Dog*
# ..                            ...
# 130                       Distant
# 131           Don't Worry Darling
# 132  Puss in Boots: The Last Wish
# 133                          Bros
# 134                           NaN
#
#                                          Cast and crew  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 130  Josh Gordon & Will Speck (directors); Spenser ...
# 131  Olivia Wilde (director); Katie Silberman, Care...
# 132  Joel Crawford (director); Antonio Banderas, Sa...
# 133  Nicholas Stoller (director/screenplay); Billy ...
# 134                                                NaN
#
#                                               genres
# 0                             Crime Mystery Thriller
# 1                                   Action Adventure
# 2                            Horror Mystery Thriller
# 3                          Action Documentary Comedy
# 4                                       Drama Comedy
# ..                                               ...
# 130                                            Drama
# 131                           Drama Mystery Thriller
# 132  Animation Adventure Comedy Family Fantasy Drama
# 133          Adventure Comedy Family Science Fiction
# 134                                           Comedy
#
# [135 rows x 3 columns]

# %%
df_2022 = df_2022.dropna(how='any')

# %%
df_2022['director_name'] = df_2022['Cast and crew'].map(lambda x: get_director(str(x)))

# %%
df_2022['actor_1_name'] = df_2022['Cast and crew'].map(lambda x: get_actor1(x))

# %%
df_2022['actor_2_name'] = df_2022['Cast and crew'].map(lambda x: get_actor2(x))

# %%
df_2022['actor_3_name'] = df_2022['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2022
# Out:
#                                     Title  \
# 10                                The 355
# 11                           The Commando
# 12               The Legend of La Llorona
# 13                                 Scream
# 14      Hotel Transylvania: Transformania
# ..                                    ...
# 129  Are You There God? It's Me, Margaret
# 130                               Distant
# 131                   Don't Worry Darling
# 132          Puss in Boots: The Last Wish
# 133                                  Bros
#
#                                          Cast and crew  \
# 10   Simon Kinberg (director/screenplay); Theresa R...
# 11   Asif Akbar (director); Koji Steven Sakai (scre...
# 12   Patricia Harris Seeley (director/screenplay); ...
# 13   Matt Bettinelli-Olpin, Tyler Gillett (director...
# 14   Jennifer Kluska, Derek Drymon (directors); Amo...
# ..                                                 ...
# 129  Kelly Fremon Craig (director/screenplay); Abby...
# 130  Josh Gordon & Will Speck (directors); Spenser ...
# 131  Olivia Wilde (director); Katie Silberman, Care...
# 132  Joel Crawford (director); Antonio Banderas, Sa...
# 133  Nicholas Stoller (director/screenplay); Billy ...
#
#                                               genres  \
# 10                                   Action Thriller
# 11                             Action Crime Thriller
# 12                                   Horror Thriller
# 13                           Horror Mystery Thriller
# 14         Animation Family Fantasy Comedy Adventure
# ..                                               ...
# 129                                     Drama Comedy
# 130                                            Drama
# 131                           Drama Mystery Thriller
# 132  Animation Adventure Comedy Family Fantasy Drama
# 133          Adventure Comedy Family Science Fiction
#
#                             director_name  \
# 10                          Simon Kinberg
# 11                             Asif Akbar
# 12                 Patricia Harris Seeley
# 13   Matt Bettinelli-Olpin, Tyler Gillett
# 14          Jennifer Kluska, Derek Drymon
# ..                                    ...
# 129                    Kelly Fremon Craig
# 130              Josh Gordon & Will Speck
# 131                          Olivia Wilde
# 132                         Joel Crawford
# 133                      Nicholas Stoller
#
#                                    actor_1_name       actor_2_name  \
# 10                             Jessica Chastain     Lupita Nyong'o
# 11                                Mickey Rourke  Michael Jai White
# 12                                Autumn Reeser       Antonio Cupo
# 13                              Melissa Barrera      Mason Gooding
# 14                                 Andy Samberg       Selena Gomez
# ..                                          ...                ...
# 129                          Abby Ryder Fortson     Rachel McAdams
# 130                               Anthony Ramos        Naomi Scott
# 131                               Florence Pugh       Harry Styles
# 132  Joel Crawford (director); Antonio Banderas        Salma Hayek
# 133                               Billy Eichner    Luke Macfarlane
#
#         actor_3_name
# 10     Penélope Cruz
# 11               NaN
# 12       Danny Trejo
# 13      Jenna Ortega
# 14      Kathryn Hahn
# ..               ...
# 129     Benny Safdie
# 130  Kristofer Hivju
# 131     Olivia Wilde
# 132   Harvey Guillén
# 133         Jim Rash
#
# [121 rows x 7 columns]

# %%
df_2022 = df_2022.rename(columns={'Title':'movie_title'})
new_df22 = df_2022.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]
new_df22
# Out:
#                             director_name  \
# 10                          Simon Kinberg
# 11                             Asif Akbar
# 12                 Patricia Harris Seeley
# 13   Matt Bettinelli-Olpin, Tyler Gillett
# 14          Jennifer Kluska, Derek Drymon
# ..                                    ...
# 129                    Kelly Fremon Craig
# 130              Josh Gordon & Will Speck
# 131                          Olivia Wilde
# 132                         Joel Crawford
# 133                      Nicholas Stoller
#
#                                    actor_1_name       actor_2_name  \
# 10                             Jessica Chastain     Lupita Nyong'o
# 11                                Mickey Rourke  Michael Jai White
# 12                                Autumn Reeser       Antonio Cupo
# 13                              Melissa Barrera      Mason Gooding
# 14                                 Andy Samberg       Selena Gomez
# ..                                          ...                ...
# 129                          Abby Ryder Fortson     Rachel McAdams
# 130                               Anthony Ramos        Naomi Scott
# 131                               Florence Pugh       Harry Styles
# 132  Joel Crawford (director); Antonio Banderas        Salma Hayek
# 133                               Billy Eichner    Luke Macfarlane
#
#         actor_3_name                                           genres  \
# 10     Penélope Cruz                                  Action Thriller
# 11               NaN                            Action Crime Thriller
# 12       Danny Trejo                                  Horror Thriller
# 13      Jenna Ortega                          Horror Mystery Thriller
# 14      Kathryn Hahn        Animation Family Fantasy Comedy Adventure
# ..               ...                                              ...
# 129     Benny Safdie                                     Drama Comedy
# 130  Kristofer Hivju                                            Drama
# 131     Olivia Wilde                           Drama Mystery Thriller
# 132   Harvey Guillén  Animation Adventure Comedy Family Fantasy Drama
# 133         Jim Rash          Adventure Comedy Family Science Fiction
#
#                               movie_title
# 10                                The 355
# 11                           The Commando
# 12               The Legend of La Llorona
# 13                                 Scream
# 14      Hotel Transylvania: Transformania
# ..                                    ...
# 129  Are You There God? It's Me, Margaret
# 130                               Distant
# 131                   Don't Worry Darling
# 132          Puss in Boots: The Last Wish
# 133                                  Bros
#
# [121 rows x 6 columns]

# %%
new_df22['actor_2_name'] = new_df22['actor_2_name'].replace(np.nan, 'unknown')
new_df22['actor_3_name'] = new_df22['actor_3_name'].replace(np.nan, 'unknown')
new_df22['movie_title'] = new_df22['movie_title'].str.lower()
new_df22['comb'] = new_df22['actor_1_name'] + ' ' + new_df22['actor_2_name'] + ' '+ new_df22['actor_3_name'] + ' '+ new_df22['director_name'] +' ' + new_df22['genres']
new_df22
# Out:
#      index                         director_name  \
# 0       10                         Simon Kinberg
# 1       11                            Asif Akbar
# 2       12                Patricia Harris Seeley
# 3       13  Matt Bettinelli-Olpin, Tyler Gillett
# 4       14         Jennifer Kluska, Derek Drymon
# ..     ...                                   ...
# 116    129                    Kelly Fremon Craig
# 117    130              Josh Gordon & Will Speck
# 118    131                          Olivia Wilde
# 119    132                         Joel Crawford
# 120    133                      Nicholas Stoller
#
#                                    actor_1_name       actor_2_name  \
# 0                              Jessica Chastain     Lupita Nyong'o
# 1                                 Mickey Rourke  Michael Jai White
# 2                                 Autumn Reeser       Antonio Cupo
# 3                               Melissa Barrera      Mason Gooding
# 4                                  Andy Samberg       Selena Gomez
# ..                                          ...                ...
# 116                          Abby Ryder Fortson     Rachel McAdams
# 117                               Anthony Ramos        Naomi Scott
# 118                               Florence Pugh       Harry Styles
# 119  Joel Crawford (director); Antonio Banderas        Salma Hayek
# 120                               Billy Eichner    Luke Macfarlane
#
#         actor_3_name                                           genres  \
# 0      Penélope Cruz                                  Action Thriller
# 1            unknown                            Action Crime Thriller
# 2        Danny Trejo                                  Horror Thriller
# 3       Jenna Ortega                          Horror Mystery Thriller
# 4       Kathryn Hahn        Animation Family Fantasy Comedy Adventure
# ..               ...                                              ...
# 116     Benny Safdie                                     Drama Comedy
# 117  Kristofer Hivju                                            Drama
# 118     Olivia Wilde                           Drama Mystery Thriller
# 119   Harvey Guillén  Animation Adventure Comedy Family Fantasy Drama
# 120         Jim Rash          Adventure Comedy Family Science Fiction
#
#                               movie_title  \
# 0                                 the 355
# 1                            the commando
# 2                the legend of la llorona
# 3                                  scream
# 4       hotel transylvania: transformania
# ..                                    ...
# 116  are you there god? it's me, margaret
# 117                               distant
# 118                   don't worry darling
# 119          puss in boots: the last wish
# 120                                  bros
#
#                                                   comb
# 0    Jessica Chastain Lupita Nyong'o Penélope Cruz ...
# 1    Mickey Rourke Michael Jai White unknown Asif A...
# 2    Autumn Reeser Antonio Cupo Danny Trejo Patrici...
# 3    Melissa Barrera Mason Gooding Jenna Ortega Mat...
# 4    Andy Samberg Selena Gomez Kathryn Hahn Jennife...
# ..                                                 ...
# 116  Abby Ryder Fortson Rachel McAdams Benny Safdie...
# 117  Anthony Ramos Naomi Scott Kristofer Hivju Josh...
# 118  Florence Pugh Harry Styles Olivia Wilde Olivia...
# 119  Joel Crawford (director); Antonio Banderas Sal...
# 120  Billy Eichner Luke Macfarlane Jim Rash Nichola...
#
# [121 rows x 8 columns]

# %%
new_df22.reset_index(inplace = True)

# %%
new_df22.drop(['index'], axis = 1)
# Out:
#                             director_name  \
# 0                           Simon Kinberg
# 1                              Asif Akbar
# 2                  Patricia Harris Seeley
# 3    Matt Bettinelli-Olpin, Tyler Gillett
# 4           Jennifer Kluska, Derek Drymon
# ..                                    ...
# 116                    Kelly Fremon Craig
# 117              Josh Gordon & Will Speck
# 118                          Olivia Wilde
# 119                         Joel Crawford
# 120                      Nicholas Stoller
#
#                                    actor_1_name       actor_2_name  \
# 0                              Jessica Chastain     Lupita Nyong'o
# 1                                 Mickey Rourke  Michael Jai White
# 2                                 Autumn Reeser       Antonio Cupo
# 3                               Melissa Barrera      Mason Gooding
# 4                                  Andy Samberg       Selena Gomez
# ..                                          ...                ...
# 116                          Abby Ryder Fortson     Rachel McAdams
# 117                               Anthony Ramos        Naomi Scott
# 118                               Florence Pugh       Harry Styles
# 119  Joel Crawford (director); Antonio Banderas        Salma Hayek
# 120                               Billy Eichner    Luke Macfarlane
#
#         actor_3_name                                           genres  \
# 0      Penélope Cruz                                  Action Thriller
# 1            unknown                            Action Crime Thriller
# 2        Danny Trejo                                  Horror Thriller
# 3       Jenna Ortega                          Horror Mystery Thriller
# 4       Kathryn Hahn        Animation Family Fantasy Comedy Adventure
# ..               ...                                              ...
# 116     Benny Safdie                                     Drama Comedy
# 117  Kristofer Hivju                                            Drama
# 118     Olivia Wilde                           Drama Mystery Thriller
# 119   Harvey Guillén  Animation Adventure Comedy Family Fantasy Drama
# 120         Jim Rash          Adventure Comedy Family Science Fiction
#
#                               movie_title  \
# 0                                 the 355
# 1                            the commando
# 2                the legend of la llorona
# 3                                  scream
# 4       hotel transylvania: transformania
# ..                                    ...
# 116  are you there god? it's me, margaret
# 117                               distant
# 118                   don't worry darling
# 119          puss in boots: the last wish
# 120                                  bros
#
#                                                   comb
# 0    Jessica Chastain Lupita Nyong'o Penélope Cruz ...
# 1    Mickey Rourke Michael Jai White unknown Asif A...
# 2    Autumn Reeser Antonio Cupo Danny Trejo Patrici...
# 3    Melissa Barrera Mason Gooding Jenna Ortega Mat...
# 4    Andy Samberg Selena Gomez Kathryn Hahn Jennife...
# ..                                                 ...
# 116  Abby Ryder Fortson Rachel McAdams Benny Safdie...
# 117  Anthony Ramos Naomi Scott Kristofer Hivju Josh...
# 118  Florence Pugh Harry Styles Olivia Wilde Olivia...
# 119  Joel Crawford (director); Antonio Banderas Sal...
# 120  Billy Eichner Luke Macfarlane Jim Rash Nichola...
#
# [121 rows x 7 columns]

# %%
final_df = final_df.append(new_df22,ignore_index=True)
final_df
# Out:
#                   director_name                                actor_1_name  \
# 0                 John Lasseter                                   Tom Hanks
# 1                  Joe Johnston                              Robin Williams
# 2                 Howard Deutch                              Walter Matthau
# 3               Forest Whitaker                             Whitney Houston
# 4                 Charles Shyer                                Steve Martin
# ...                         ...                                         ...
# 37549        Kelly Fremon Craig                          Abby Ryder Fortson
# 37550  Josh Gordon & Will Speck                               Anthony Ramos
# 37551              Olivia Wilde                               Florence Pugh
# 37552             Joel Crawford  Joel Crawford (director); Antonio Banderas
# 37553          Nicholas Stoller                               Billy Eichner
#
#           actor_2_name     actor_3_name  \
# 0            Tim Allen      Don Rickles
# 1        Jonathan Hyde    Kirsten Dunst
# 2          Jack Lemmon      Ann-Margret
# 3       Angela Bassett   Loretta Devine
# 4         Diane Keaton     Martin Short
# ...                ...              ...
# 37549   Rachel McAdams     Benny Safdie
# 37550      Naomi Scott  Kristofer Hivju
# 37551     Harry Styles     Olivia Wilde
# 37552      Salma Hayek   Harvey Guillén
# 37553  Luke Macfarlane         Jim Rash
#
#                                                 genres  \
# 0                              Animation Comedy Family
# 1                             Adventure Fantasy Family
# 2                                       Romance Comedy
# 3                                 Comedy Drama Romance
# 4                                               Comedy
# ...                                                ...
# 37549                                     Drama Comedy
# 37550                                            Drama
# 37551                           Drama Mystery Thriller
# 37552  Animation Adventure Comedy Family Fantasy Drama
# 37553          Adventure Comedy Family Science Fiction
#
#                                 movie_title  \
# 0                                 toy story
# 1                                   jumanji
# 2                          grumpier old men
# 3                         waiting to exhale
# 4               father of the bride part ii
# ...                                     ...
# 37549  are you there god? it's me, margaret
# 37550                               distant
# 37551                   don't worry darling
# 37552          puss in boots: the last wish
# 37553                                  bros
#
#                                                     comb  index
# 0      Tom Hanks Tim Allen Don Rickles John Lasseter ...    NaN
# 1      Robin Williams Jonathan Hyde Kirsten Dunst Joe...    NaN
# 2      Walter Matthau Jack Lemmon Ann-Margret Howard ...    NaN
# 3      Whitney Houston Angela Bassett Loretta Devine ...    NaN
# 4      Steve Martin Diane Keaton Martin Short Charles...    NaN
# ...                                                  ...    ...
# 37549  Abby Ryder Fortson Rachel McAdams Benny Safdie...  129.0
# 37550  Anthony Ramos Naomi Scott Kristofer Hivju Josh...  130.0
# 37551  Florence Pugh Harry Styles Olivia Wilde Olivia...  131.0
# 37552  Joel Crawford (director); Antonio Banderas Sal...  132.0
# 37553  Billy Eichner Luke Macfarlane Jim Rash Nichola...  133.0
#
# [37554 rows x 8 columns]

# %%
final_df = final_df.dropna(how='any')
final_df.to_csv('./datasets/final_data.csv',index=False)
